# %%
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
# Each row of the data correponds to a minute in time.
data = pd.read_csv("/home/arancium/ucihydraulic/Data/Data.csv")
data['Time'] = range(len(data))
data['Time'] = pd.to_datetime(data['Time'], unit='m', origin=pd.Timestamp('2023-09-23 00:00:00'))
data.set_index('Time', inplace=True)
data.head()
# Out:
#                             PS1         PS2       PS3  PS4       PS5  \
# Time
# 2023-09-23 00:00:00  160.673492  109.466914  1.991475  0.0  9.842170
# 2023-09-23 00:01:00  160.603320  109.354890  1.976234  0.0  9.635142
# 2023-09-23 00:02:00  160.347720  109.158845  1.972224  0.0  9.530548
# 2023-09-23 00:03:00  160.188088  109.064807  1.946576  0.0  9.438827
# 2023-09-23 00:04:00  160.000472  108.931434  1.922707  0.0  9.358762
#
#                           PS6         EPS1       FS1        FS2        TS1  \
# Time
# 2023-09-23 00:00:00  9.728098  2538.929167  6.709815  10.304592  35.621983
# 2023-09-23 00:01:00  9.529488  2531.498900  6.715315  10.403098  36.676967
# 2023-09-23 00:02:00  9.427949  2519.928000  6.718522  10.366250  37.880800
# 2023-09-23 00:03:00  9.337430  2511.541633  6.720565  10.302678  38.879050
# 2023-09-23 00:04:00  9.260636  2503.449500  6.690308  10.237750  39.803917
#
#                      ...        TS4       VS1         CE        CP         SE  \
# ...

# %%
targets_minutes = data[:-5]
targets_minutes
# Out:
#                             PS1         PS2       PS3        PS4       PS5  \
# Time
# 2023-09-23 00:00:00  160.673492  109.466914  1.991475   0.000000  9.842170
# 2023-09-23 00:01:00  160.603320  109.354890  1.976234   0.000000  9.635142
# 2023-09-23 00:02:00  160.347720  109.158845  1.972224   0.000000  9.530548
# 2023-09-23 00:03:00  160.188088  109.064807  1.946576   0.000000  9.438827
# 2023-09-23 00:04:00  160.000472  108.931434  1.922707   0.000000  9.358762
# ...                         ...         ...       ...        ...       ...
# 2023-09-24 12:35:00  161.207317  109.759292  2.002790  10.201999  9.971289
# 2023-09-24 12:36:00  161.226700  109.788356  2.001049  10.204081  9.973693
# 2023-09-24 12:37:00  161.235612  109.799786  2.000534  10.205982  9.977087
# 2023-09-24 12:38:00  161.244217  109.807411  1.996837  10.207068  9.978511
# 2023-09-24 12:39:00  161.235373  109.801761  1.994050  10.205390  9.976496
#
# ...

# %%
data.describe().T.round(2)
# Out:
#                               count     mean    std      min      25%  \
# PS1                          2205.0   160.49   4.70   155.39   158.10
# PS2                          2205.0   109.38   4.99   104.41   106.96
# PS3                          2205.0     1.75   0.25     0.84     1.73
# PS4                          2205.0     2.60   4.28     0.00     0.00
# PS5                          2205.0     9.16   0.58     8.37     8.55
# PS6                          2205.0     9.08   0.55     8.32     8.49
# EPS1                         2205.0  2495.51  73.84  2361.75  2442.93
# FS1                          2205.0     6.20   1.03     2.02     6.39
# FS2                          2205.0     9.65   0.45     8.86     9.20
# TS1                          2205.0    45.42   7.99    35.31    36.24
# TS2                          2205.0    50.37   7.40    40.86    41.86
# TS3                          2205.0    47.66   7.45    38.25    39.12
# ...

# %% [markdown]
# About the describe:
#
# Pressures:
#
# PS1 y PS2, media y mediana están cercanas, parecieran tener un comportamiento similar.
# PS3 Comportamiento normal, pero están en otra "Escala"
# PS4, tiene una desviacion muy grande.
# PS5 y PS6 poseen un comportamiento similar entre si.
#
# Motor Power:
#
# EPS1 (Motor power): Posee un comportamiento normal al parecer.
#
# Volume Flow:
#
# FS1 y FS2 (Volume Flow): Posee un comportamiento normal al parecer.
#
# Temperaturas:
#
# Los 4 sensores de temperaturas se comportan de una forma similar.
#
# Vibracion:
#
# VS1: se ve estable
#
# CE: Fluctuante.
#
# CP: Estable
#
# SE: Estable

# %% [markdown]
# # Corrrelation

# %%
# Create a mask to hide the upper triangular part (including the diagonal)
corr = data.corr()

mask = np.tril(np.ones_like(corr, dtype=bool))

# Apply the mask to the correlation matrix
masked_corr = np.where(mask, corr, np.nan)

fig = ff.create_annotated_heatmap(
    z=masked_corr.round(2),
    x=list(corr.index.values),
    y=list(corr.columns.values),       
    xgap=5, ygap=5,
    zmin=-1, zmax=1,
    colorscale='RdYlGn',
    colorbar_thickness=3,
    colorbar_ticklen=0,
    showscale=False,  # Set this to False to hide the color scale for NaN values
    annotation_text=masked_corr.round(2),  # Add annotation text with values
    font_colors=['black', 'white'],  # Specify font colors for positive and negative values
)

fig.update_layout(title_text='<b>Lower Triangular Correlation Matrix (cont. features)<b>',
                  title_x=0.5,
                  titlefont={'size': 24},
                  width=1000, height=1000,
                  xaxis_showgrid=False,
                  xaxis={'side': 'bottom'},
                  yaxis_showgrid=False,
                  yaxis_autorange='reversed',                   
                  paper_bgcolor=None,
                  )
fig.show()

# %%
Vars = list(data)
cor = data.corr()

for var in Vars:
    cor_target = abs(cor[var])
    relevant_features = cor_target[cor_target > 0.5].index.tolist()
    print(f"Relevant features for '{var}': {relevant_features}")
# Out:
# Relevant features for 'PS1': ['PS1', 'PS2', 'PS3', 'EPS1', 'FS1', 'SE']
# Relevant features for 'PS2': ['PS1', 'PS2', 'PS3', 'EPS1', 'FS1', 'VS1', 'SE']
# Relevant features for 'PS3': ['PS1', 'PS2', 'PS3', 'PS5', 'PS6', 'FS1', 'FS2', 'TS1', 'TS2', 'TS3', 'TS4', 'VS1', 'CE', 'CP', 'SE', 'Cooler condition']
# Relevant features for 'PS4': ['PS4', 'PS5', 'PS6', 'FS2', 'TS1', 'TS2', 'TS3', 'TS4', 'VS1', 'CE', 'CP', 'Cooler condition']
# Relevant features for 'PS5': ['PS3', 'PS4', 'PS5', 'PS6', 'FS2', 'TS1', 'TS2', 'TS3', 'TS4', 'VS1', 'CE', 'CP', 'Cooler condition']
# Relevant features for 'PS6': ['PS3', 'PS4', 'PS5', 'PS6', 'FS2', 'TS1', 'TS2', 'TS3', 'TS4', 'VS1', 'CE', 'CP', 'Cooler condition']
# Relevant features for 'EPS1': ['PS1', 'PS2', 'EPS1', 'FS1', 'SE']
# Relevant features for 'FS1': ['PS1', 'PS2', 'PS3', 'EPS1', 'FS1', 'FS2', 'TS1', 'TS3', 'TS4', 'VS1', 'SE']
# ...

# %%
fig1 = px.line(data,
               x=data.index,
               y=['PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'PS6'],
               title="Pressures"
               )
fig1.show()

# %%
fig1 = px.line(data,
               x=data.index,
               y=data.columns[0:6],
               title="Pressures"
               )

fig2 = px.line(data,
               x=data.index,
               y=data.columns[6],
               title = "Motor power"
               )

fig3 = px.line(data,
               x=data.index,
               y=data.columns[7:9],
               title="Volume flows")
                

fig4 = px.line(data,
               x=data.index,
               y=data.columns[9:13],
               title="Temperatures")

fig5 = px.line(data,
               x=data.index, 
               y=data.columns[13],
               title="Vibrations")

fig6 = px.line(data,
               x=data.index, 
               y=data.columns[14:17],
               title="Others")


fig7 = px.line(data,
               x=data.index, 
               y=data.columns[17:19])

fig8 = px.line(data,
               x=data.index, 
               y=data.columns[19:21])

fig9 = px.line(data,
               x=data.index,
               y=data.columns[21])

fig1.show()
fig2.show()
fig3.show()
fig4.show()
fig5.show()
fig6.show()
fig7.show()
fig8.show()
fig9.show()

# %%
data['Cooler condition'].value_counts()
data['Valve condition'].value_counts()
# Out:
# Valve condition
# 100    1125
# 73      360
# 80      360
# 90      360
# Name: count, dtype: int64

# %%
data['stable flag'].value_counts()
# Out:
# stable flag
# 0    1449
# 1     756
# Name: count, dtype: int64
